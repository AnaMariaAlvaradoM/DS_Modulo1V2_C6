# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.decomposition import PCA
import warnings
warnings.filterwarnings('ignore')

print("Librerías cargadas correctamente")
# Out:
# Librerías cargadas correctamente

# %%
df = pd.read_csv('viajaco_colombia.csv')

print(f"Dimensiones del dataset: {df.shape}")
print(f"→ {df.shape[0]} viajeros, {df.shape[1]} variables\n")
df.head()
# Out:
# Dimensiones del dataset: (1500, 10)
# → 1500 viajeros, 10 variables
#   viajero_id ciudad_origen destino_preferido tipo_viaje        canal_reserva  \
# 0    VCO0001     Manizales      Eje Cafetero   Aventura            App móvil
# 1    VCO0002        Bogotá          Medellín   Cultural      Reserva directa
# 2    VCO0003  Barranquilla        San Andrés   Descanso  Agencia tradicional
# 3    VCO0004  Barranquilla         Cartagena   Descanso      Reserva directa
# 4    VCO0005        Bogotá       Santa Marta   Aventura        Recomendación
#
#    edad  gasto_promedio_cop  frecuencia_anual  noches_promedio  satisfaccion
# 0    18              345617               2.7              4.1           3.7
# 1    46             1940263               1.2              2.2           5.0
# 2    40             1309613               3.2              3.2           4.6
# 3    33              932102               1.7              6.6           4.0
# ...

# %%
print("Tipos de datos:")
print(df.dtypes)
print(f"\nValores nulos por columna:")
print(df.isnull().sum())
# Out:
# Tipos de datos:
# viajero_id                str
# ciudad_origen             str
# destino_preferido         str
# tipo_viaje                str
# canal_reserva             str
# edad                    int64
# gasto_promedio_cop      int64
# frecuencia_anual      float64
# noches_promedio       float64
# satisfaccion          float64
# dtype: object
#
# Valores nulos por columna:
# viajero_id            0
# ciudad_origen         0
# destino_preferido     0
# tipo_viaje            0
# canal_reserva         0
# edad                  0
# gasto_promedio_cop    0
# frecuencia_anual      0
# noches_promedio       0
# satisfaccion          0
# dtype: int64

# %%
df.describe().round(2)
# Out:
#           edad  gasto_promedio_cop  frecuencia_anual  noches_promedio  \
# count  1500.00             1500.00           1500.00          1500.00
# mean     34.35          1189147.06              2.88             4.38
# std       8.82           860673.49              1.55             1.51
# min      18.00           150000.00              1.00             1.00
# 25%      27.00           381947.50              1.70             3.30
# 50%      34.00          1088448.00              2.40             4.20
# 75%      41.00          1751357.00              4.00             5.40
# max      60.00          3310726.00              7.80            10.00
#
#        satisfaccion
# count       1500.00
# mean           4.33
# std            0.45
# min            2.50
# 25%            4.00
# 50%            4.40
# 75%            4.70
# max            5.00

# %%
variables_numericas = ['edad', 'gasto_promedio_cop', 'frecuencia_anual', 
                       'noches_promedio', 'satisfaccion']

X = df[variables_numericas].copy()

scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

print(f"Shape de X_scaled: {X_scaled.shape}")
print(f"\nMedia por columna después del escalado (debe ser ≈ 0):")
print(X_scaled.mean(axis=0).round(4))
print(f"\nDesviación estándar por columna después del escalado (debe ser ≈ 1):")
print(X_scaled.std(axis=0).round(4))
# Out:
# Shape de X_scaled: (1500, 5)
#
# Media por columna después del escalado (debe ser ≈ 0):
# [-0.  0. -0. -0.  0.]
#
# Desviación estándar por columna después del escalado (debe ser ≈ 1):
# [1. 1. 1. 1. 1.]

# %%
inercias = []
valores_k = range(2, 11)

for k in valores_k:
    kmeans = KMeans(n_clusters=k, random_state=42, n_init=10)
    kmeans.fit(X_scaled)
    inercias.append(kmeans.inertia_)
    print(f"K={k:2d} → Inercia: {kmeans.inertia_:,.2f}")

print("\nCálculo completado")
# Out:
# K= 2 → Inercia: 4,028.70
# K= 3 → Inercia: 3,102.55
# K= 4 → Inercia: 2,629.23
# K= 5 → Inercia: 2,346.78
# K= 6 → Inercia: 2,173.35
# K= 7 → Inercia: 2,042.41
# K= 8 → Inercia: 1,913.35
# K= 9 → Inercia: 1,803.19
# K=10 → Inercia: 1,715.13
#
# Cálculo completado

# %%
plt.figure(figsize=(10, 5))
plt.plot(valores_k, inercias, marker='o', color='#c040e8', linewidth=2.5, 
         markersize=8, markerfacecolor='white', markeredgewidth=2)
plt.xlabel('Número de Clusters (K)', fontsize=12)
plt.ylabel('Inercia (WCSS)', fontsize=12)
plt.title('Método del Codo — ViajaCo Colombia', fontsize=14, fontweight='bold')
plt.xticks(valores_k)
plt.grid(True, alpha=0.3)
plt.tight_layout()
plt.show()

# %%
kmeans_final = KMeans(n_clusters=3, random_state=42, n_init=10)
kmeans_final.fit(X_scaled)

df['cluster'] = kmeans_final.labels_

print(f"Clusters asignados: {sorted(df['cluster'].unique())}")
print(f"\nDistribución de clusters (cantidad de viajeros):")
print(df['cluster'].value_counts().sort_index())
print(f"\nPorcentaje de viajeros por cluster:")
print((df['cluster'].value_counts(normalize=True).sort_index() * 100).round(1).astype(str) + '%')
# Out:
# Clusters asignados: [np.int32(0), np.int32(1), np.int32(2)]
#
# Distribución de clusters (cantidad de viajeros):
# cluster
# 0    512
# 1    401
# 2    587
# Name: count, dtype: int64
#
# Porcentaje de viajeros por cluster:
# cluster
# 0    34.1%
# 1    26.7%
# 2    39.1%
# Name: proportion, dtype: str

# %%
perfil_numerico = df.groupby('cluster')[variables_numericas].mean().round(2)
print("=== PERFIL PROMEDIO POR CLUSTER ===\n")
print(perfil_numerico.to_string())
# Out:
# === PERFIL PROMEDIO POR CLUSTER ===
#
#           edad  gasto_promedio_cop  frecuencia_anual  noches_promedio  satisfaccion
# cluster
# 0        37.24          1202814.17              2.12             5.75          4.38
# 1        43.42          2370789.96              1.53             3.96          4.62
# 2        25.64           370005.05              4.47             3.46          4.09

# %%
print("=== TIPO DE VIAJE POR CLUSTER ===")
print(df.groupby('cluster')['tipo_viaje'].value_counts().unstack(fill_value=0))

print("\n=== DESTINO PREFERIDO POR CLUSTER ===")
print(df.groupby('cluster')['destino_preferido'].value_counts().unstack(fill_value=0))

print("\n=== CANAL DE RESERVA POR CLUSTER ===")
print(df.groupby('cluster')['canal_reserva'].value_counts().unstack(fill_value=0))
# Out:
# === TIPO DE VIAJE POR CLUSTER ===
# tipo_viaje  Aventura  Cultural  Descanso  Ecoturismo  Gastronómico
# cluster
# 0                  4       104       269           2           133
# 1                  0       165        89           0           147
# 2                272       132         8         172             3
#
# === DESTINO PREFERIDO POR CLUSTER ===
# destino_preferido  Amazonas  Cartagena  Eje Cafetero  Medellín  San Andrés  \
# cluster
# 0                         2        218            59         3         145
# 1                         0        148             8        55         108
# 2                       130          6           231         0           5
#
# destino_preferido  Santa Marta  Villa de Leyva
# cluster
# 0                           82               3
# 1                            4              78
# 2                          133              82
#
# === CANAL DE RESERVA POR CLUSTER ===
# ...

# %%
nombres_cluster = {
    0: 'El joven',   
    1: 'La Familia',       
    2: 'El Ejecutivo'      
}
df['perfil'] = df['cluster'].map(nombres_cluster)

print(df[['viajero_id', 'cluster', 'perfil', 'gasto_promedio_cop', 
          'frecuencia_anual', 'tipo_viaje']].head(15).to_string())
# Out:
#    viajero_id  cluster        perfil  gasto_promedio_cop  frecuencia_anual    tipo_viaje
# 0     VCO0001        2  El Ejecutivo              345617               2.7      Aventura
# 1     VCO0002        1    La Familia             1940263               1.2      Cultural
# 2     VCO0003        1    La Familia             1309613               3.2      Descanso
# 3     VCO0004        0      El joven              932102               1.7      Descanso
# 4     VCO0005        2  El Ejecutivo              310989               2.0      Aventura
# 5     VCO0006        2  El Ejecutivo              235099               5.1      Aventura
# 6     VCO0007        2  El Ejecutivo              405513               6.3      Aventura
# 7     VCO0008        1    La Familia             2225307               1.0  Gastronómico
# 8     VCO0009        0      El joven             1417044               2.0  Gastronómico
# ...

# %% [markdown]
# # PARTE 2

# %%
pca_viz = PCA(n_components=2, random_state=42)
X_pca_2d = pca_viz.fit_transform(X_scaled)

varianza_explicada = pca_viz.explained_variance_ratio_
print(f"Varianza explicada por PC1: {varianza_explicada[0]*100:.1f}%")
print(f"Varianza explicada por PC2: {varianza_explicada[1]*100:.1f}%")
print(f"Varianza total explicada (PC1+PC2): {sum(varianza_explicada)*100:.1f}%")
print(f"\n→ Con solo 2 dimensiones, retenemos el {sum(varianza_explicada)*100:.1f}%")
print(f"→ Perdemos el {(1-sum(varianza_explicada))*100:.1f}% de la información")
# Out:
# Varianza explicada por PC1: 56.8%
# Varianza explicada por PC2: 18.6%
# Varianza total explicada (PC1+PC2): 75.3%
#
# → Con solo 2 dimensiones, retenemos el 75.3%
# → Perdemos el 24.7% de la información

# %%
colores = {0: '#c040e8', 1: '#4a5af0', 2: '#00c9a7'}

fig, ax = plt.subplots(figsize=(12, 7))

for cluster_id in sorted(df['cluster'].unique()):
    mask = df['cluster'] == cluster_id
    ax.scatter(
        X_pca_2d[mask, 0],
        X_pca_2d[mask, 1],
        c=colores[cluster_id],
        label=f"Cluster {cluster_id}: {nombres_cluster[cluster_id]}",
        alpha=0.6,
        s=40,
        edgecolors='none'
    )

# Centroides proyectados al espacio PCA
centroides_pca = pca_viz.transform(kmeans_final.cluster_centers_)
ax.scatter(centroides_pca[:, 0], centroides_pca[:, 1],
           c='white', marker='*', s=300, zorder=5,
           edgecolors='black', linewidths=1.5, label='Centroides')

ax.set_xlabel(f'PC1 ({varianza_explicada[0]*100:.1f}% varianza explicada)', fontsize=11)
ax.set_ylabel(f'PC2 ({varianza_explicada[1]*100:.1f}% varianza explicada)', fontsize=11)
ax.set_title('Segmentación de Viajeros ViajaCo Colombia — K-Means + PCA', 
             fontsize=14, fontweight='bold')
ax.legend(fontsize=10)
ax.grid(True, alpha=0.2)
plt.tight_layout()
plt.show()

# %%
pca_full = PCA(random_state=42)
pca_full.fit(X_scaled)

varianza_por_componente = pca_full.explained_variance_ratio_
varianza_acumulada = np.cumsum(varianza_por_componente)

fig, axes = plt.subplots(1, 2, figsize=(14, 5))

# Gráfico 1: barras de varianza por componente
axes[0].bar(range(1, len(varianza_por_componente)+1),
            varianza_por_componente * 100,
            color='#c040e8', alpha=0.8)
axes[0].set_xlabel('Componente Principal', fontsize=11)
axes[0].set_ylabel('Varianza Explicada (%)', fontsize=11)
axes[0].set_title('Varianza por Componente', fontsize=12, fontweight='bold')
axes[0].set_xticks(range(1, len(varianza_por_componente)+1))
axes[0].set_xticklabels([f'PC{i}' for i in range(1, len(varianza_por_componente)+1)])

# Gráfico 2: curva acumulada
axes[1].plot(range(1, len(varianza_acumulada)+1),
             varianza_acumulada * 100,
             marker='o', color='#4a5af0', linewidth=2.5, markersize=8)
axes[1].axhline(y=80, color='#c040e8', linestyle='--', alpha=0.7, label='Umbral 80%')
axes[1].axhline(y=90, color='#00c9a7', linestyle='--', alpha=0.7, label='Umbral 90%')
axes[1].set_xlabel('Número de Componentes Acumulados', fontsize=11)
axes[1].set_ylabel('Varianza Acumulada (%)', fontsize=11)
axes[1].set_title('Varianza Acumulada', fontsize=12, fontweight='bold')
axes[1].set_xticks(range(1, len(varianza_acumulada)+1))
axes[1].legend()
axes[1].grid(True, alpha=0.3)

plt.tight_layout()
plt.show()

print("\nVarianza acumulada por número de componentes:")
for i, va in enumerate(varianza_acumulada):
    print(f"  {i+1} componente(s): {va*100:.1f}%")
# Out:
# Varianza acumulada por número de componentes:
#   1 componente(s): 56.8%
#   2 componente(s): 75.3%
#   3 componente(s): 89.9%
#   4 componente(s): 95.7%
#   5 componente(s): 100.0%

# %%
print("=" * 65)
print("   RESUMEN EJECUTIVO — ViajaCo Colombia")
print("   Segmentación de Viajeros · K-Means · K=3")
print("=" * 65)

for cluster_id in sorted(df['cluster'].unique()):
    perfil_nombre = nombres_cluster[cluster_id]
    datos = df[df['cluster'] == cluster_id]
    n = len(datos)
    pct = n / len(df) * 100

    print(f"\n{'─'*65}")
    print(f"  PERFIL {cluster_id}: {perfil_nombre.upper()}")
    print(f"{'─'*65}")
    print(f"  Tamaño:            {n} viajeros ({pct:.1f}% del total)")
    print(f"  Gasto promedio:    ${datos['gasto_promedio_cop'].mean():>12,.0f} COP")
    print(f"  Viajes al año:     {datos['frecuencia_anual'].mean():.1f}")
    print(f"  Noches promedio:   {datos['noches_promedio'].mean():.1f}")
    print(f"  Edad promedio:     {datos['edad'].mean():.0f} años")
    print(f"  Tipo viaje top:    {datos['tipo_viaje'].mode()[0]}")
    print(f"  Destino top:       {datos['destino_preferido'].mode()[0]}")
    print(f"  Canal top:         {datos['canal_reserva'].mode()[0]}")
# Out:
# ...
#    RESUMEN EJECUTIVO — ViajaCo Colombia
#    Segmentación de Viajeros · K-Means · K=3
# ...
#
# ─────────────────────────────────────────────────────────────────
#   PERFIL 0: EL JOVEN
# ─────────────────────────────────────────────────────────────────
#   Tamaño:            512 viajeros (34.1% del total)
#   Gasto promedio:    $   1,202,814 COP
#   Viajes al año:     2.1
#   Noches promedio:   5.8
#   Edad promedio:     37 años
#   Tipo viaje top:    Descanso
#   Destino top:       Cartagena
#   Canal top:         Agencia tradicional
#
# ─────────────────────────────────────────────────────────────────
#   PERFIL 1: LA FAMILIA
# ─────────────────────────────────────────────────────────────────
#   Tamaño:            401 viajeros (26.7% del total)
#   Gasto promedio:    $   2,370,790 COP
#   Viajes al año:     1.5
#   Noches promedio:   4.0
#   Edad promedio:     43 años
#   Tipo viaje top:    Cultural
#   Destino top:       Cartagena
#   Canal top:         Reserva directa
#
# ...
